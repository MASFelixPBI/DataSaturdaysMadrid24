# %%
from pyspark.sql.functions import explode, sequence, to_date
from pyspark.sql.functions import to_date, year, quarter, month, dayofmonth, date_format, weekofyear

beginDate = '2012-01-01'
endDate = '2024-12-31'

(
  spark.sql(f"select explode(sequence(to_date('{beginDate}'), to_date('{endDate}'), interval 1 day)) as calendarDate")
    .createOrReplaceTempView('dates')
)
# Out:
# StatementMeta(, 2aa04bad-ab05-4f7e-a167-b015305d3629, 36, Finished, Available, Finished)

# %%
# %%sql
# select * from dates
# order by calendarDate asc
# Out:
# StatementMeta(, 2aa04bad-ab05-4f7e-a167-b015305d3629, 37, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 1 fields>

# %%
# %%sql
# select
#     CalendarDate as Date,
#     year(calendarDate) as Year,
#     case when
#         month(calendarDate) <4 then "Q1"
#     when
#         month(calendarDate) <7 then "Q2"
#     when
#         month(calendarDate) <10 then "Q3"
#     else
#         "Q4" end
#
#          as Quarter,
#     month(calendarDate) as Month_Number,
#     date_format(calendarDate, 'MMMM') as Month,
#     extract(week FROM calendarDate) Week,
#     date_format(calendarDate, 'EEEE') as CalendarDay,
#     dayofweek(calendarDate) AS WeekDay,
#     concat(year(calendarDate) ,"-",  date_format(calendarDate, 'MM')) as Period
#
#     from
#     dates
#     order by
#         calendarDate
# Out:
# StatementMeta(, 2aa04bad-ab05-4f7e-a167-b015305d3629, 38, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 9 fields>

# %%
# %%sql
# CREATE OR REPLACE TABLE  Calendar
#
# select
#     CalendarDate as Date,
#     year(calendarDate) as Year,
#     case when
#         month(calendarDate) <4 then "Q1"
#     when
#         month(calendarDate) <7 then "Q2"
#     when
#         month(calendarDate) <10 then "Q3"
#     else
#         "Q4" end
#
#          as Quarter,
#     month(calendarDate) as Month_Number,
#     date_format(calendarDate, 'MMMM') as Month,
#     extract(week FROM calendarDate) Week,
#     date_format(calendarDate, 'EEEE') as CalendarDay,
#     dayofweek(calendarDate) AS WeekDay,
#     concat(year(calendarDate) ,"-",  date_format(calendarDate, 'MM')) as Period
#
# from
#     dates
# order by
#     calendarDate
# ;
# Out:
# StatementMeta(, 2aa04bad-ab05-4f7e-a167-b015305d3629, 40, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
df = spark.sql("SELECT * FROM LH_Fabric.calendar order by Date desc LIMIT 1000 ")
display(df)
# Out:
# StatementMeta(, 2aa04bad-ab05-4f7e-a167-b015305d3629, 41, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5ecf94db-8fe6-401a-a98b-0f4f22212987)

# %%
df = spark.sql("SELECT COUNT(*) FROM LH_Fabric.calendar")
display(df)
# Out:
# StatementMeta(, 2aa04bad-ab05-4f7e-a167-b015305d3629, 42, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d802772c-dfdf-4718-bef8-e0aa0502eff8)
